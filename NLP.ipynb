# %%
# Natural language processing

# %%
# !git push -u origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# First, let's configure your Git user email (replace `you@example.com` with your actual email address). Your Git username `devarshilalani` is already set from your previous command.

# %%
# !git config --global user.email "devatshilalani" # Replace with your email address

# %% [markdown]
# Next, we'll add your `NLP.ipynb` file to the staging area and commit it. **Please ensure your `NLP.ipynb` file is saved in the `/content/` directory.** If you want to push the *current* notebook you are working on, you may need to manually save it as `NLP.ipynb` in your Colab environment (File -> Save a copy) or ensure it's in the `/content/` directory.

# %%
# Add the NLP.ipynb file to the staging area
# !git add NLP.ipynb

# Commit the changes
# !git commit -m "Add NLP notebook"

# %% [markdown]
# Now, let's ensure the remote origin is set to the correct HTTPS URL and then push your changes. When prompted for credentials, use your GitHub username and a Personal Access Token (PAT) as the password.

# %%
# Check current remote setup (optional, to see if 'origin' already points correctly)
# !git remote -v

# Set the remote origin to the HTTPS URL for your repository
# This overwrites any existing 'origin' remote if it was configured differently (e.g., SSH)
# !git remote set-url origin https://github.com/devarshilalani/Natural_language_processing.git

# Push the changes to the 'main' branch
# You will be prompted to enter your GitHub username and then your Personal Access Token (PAT) as the password.
# !git push -u origin main

# %% [markdown]
# **Important:** When the `git push` command asks for your password, **do not use your GitHub account password**. Instead, generate a **Personal Access Token (PAT)** from your GitHub settings (under Developer settings -> Personal access tokens) and use that as the password.
#
# Also, please ensure your repository on GitHub has a `main` branch. If it's still using `master`, you might need to adjust `git push -u origin main` to `git push -u origin master` or rename your branch on GitHub.

# %%
# !git config --global user.name "devarshilalani"
