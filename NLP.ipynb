# %% [markdown]
# <a href="https://colab.research.google.com/github/devarshilalani/Natural_language_processing/blob/master/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Natural language processing
